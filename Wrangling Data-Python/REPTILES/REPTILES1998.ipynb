# %% [markdown]
# Author: Ishika Wikramanayake
#
# Start_Date: 26-Aug-2019
#
# End_Date: 30-Aug-2019

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import folium

# %%
# ACT

Lizards__Snakes = pd.read_csv("./Datasets/AUSTRALIAN CAPITAL TERRITORY/1998/Reptiles/Lizards__Snakes.csv")
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/AUSTRALIAN CAPITAL TERRITORY/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Lizards__Snakes, Tortoises__Turtles__Terrapins])

# NSW

Lizards__Snakes = pd.read_csv("./Datasets/NEW SOUTH WALES/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/NEW SOUTH WALES/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# NT

Crocodiles = pd.read_csv("./Datasets/NORTHERN TERRITORY/1998/Reptiles/Crocodiles.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Crocodiles])
Lizards__Snakes = pd.read_csv("./Datasets/NORTHERN TERRITORY/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/NORTHERN TERRITORY/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# QLD

Lizards__Snakes = pd.read_csv("./Datasets/QUEENSLAND/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/QUEENSLAND/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# SA

Lizards__Snakes = pd.read_csv("./Datasets/SOUTH AUSTRALIA/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/SOUTH AUSTRALIA/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# TAS

Lizards__Snakes = pd.read_csv("./Datasets/TASMANIA/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/TASMANIA/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# VIC

Lizards__Snakes = pd.read_csv("./Datasets/VICTORIA/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/VICTORIA/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# WA

Lizards__Snakes = pd.read_csv("./Datasets/WESTERN AUSTRALIA/1998/Reptiles/Lizards__Snakes.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Lizards__Snakes])
Tortoises__Turtles__Terrapins = pd.read_csv("./Datasets/WESTERN AUSTRALIA/1998/Reptiles/Tortoises__Turtles__Terrapins.csv")
Reptiles_1998 = pd.concat([Reptiles_1998, Tortoises__Turtles__Terrapins])

# %% [markdown]
# ### 1998

# %%
# Drop unnecessary columns in 1998

Reptiles_1998 = Reptiles_1998.drop(columns=['Record ID', 'Catalogue Number', 'Taxon Concept GUID', 'Scientific Name - original', 'Species', 'Subspecies', 'Institution ID', 'Institution', 'Collection ID', 'Collection', 'Locality', 'Coordinate Precision', 'IMCRA 4 Regions', 'Minimum elevation in meters', 'Local Government Areas 2011', 'Maximum elevation in meters', 'Minimum depth in meters', 'Maximum depth in meters', 'Sex', 'Preparations', 'Outlier for layer', 'Data Resource ID', 'Data Resource Name', 'Licence', 'Institution Code', 'Collection Code', 'Geodetic datum - original', 'Coordinate Uncertainty in Metres', 'Individual count', 'Collector', 'Month', 'Day', 'Event Date - parsed', 'Verbatim event date', 'Basis Of Record - original', 'Basis Of Record', 'Occurrence status', 'Taxonomic Quality', 'Order', 'IBRA 7 Regions', 'Location Quality', 'Latitude - original', 'Longitude - original', 'Vernacular name'])

# %%
# Check how many null values are in their in all the columns for 1998

Reptiles_1998.isnull().sum()
# Out:
# Vernacular name - original    6347
# Scientific Name                  0
# Taxon Rank                       0
# Kingdom                          0
# Phylum                           0
# Class                            0
# Family                           0
# Genus                            0
# Latitude                         0
# Longitude                        0
# Country - parsed                 0
# State - parsed                   0
# Year                             0
# dtype: int64

# %%
# Manually add the English names to the rows with null values for 1998

Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Intellagama lesueurii', 'Vernacular name - original'] = 'Australian water dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Christinus marmoratus', 'Vernacular name - original'] = 'Christinus marmoratus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus panoptes', 'Vernacular name - original'] = 'Argus monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus varius', 'Vernacular name - original'] = 'Lace monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemidactylus frenatus', 'Vernacular name - original'] = 'Common house gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua scincoides', 'Vernacular name - original'] = 'Eastern blue-tongued lizard'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus mertensi', 'Vernacular name - original'] = 'Mertens\' water monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Intellagama lesueurii lesueurii', 'Vernacular name - original'] = 'Australian water dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota', 'Vernacular name - original'] = 'Carpet python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Dendrelaphis punctulatus', 'Vernacular name - original'] = 'Dendrelaphis punctulatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua rugosa', 'Vernacular name - original'] = 'Tiliqua rugosa'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura macquarii', 'Vernacular name - original'] = 'Emydura macquarii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Crocodylus johnstoni', 'Vernacular name - original'] = 'Freshwater crocodile'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lampropholis guichenoti', 'Vernacular name - original'] = 'Common garden skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus mitchelli', 'Vernacular name - original'] = 'Mitchell\'s water monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carettochelys insculpta', 'Vernacular name - original'] = 'Pig-nosed turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chelodina (Chelodina) longicollis', 'Vernacular name - original'] = 'Eastern long-necked turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eulamprus quoyii', 'Vernacular name - original'] = 'Eulamprus quoyii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus buchananii', 'Vernacular name - original'] = 'Buchanan\'s snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pogona barbata', 'Vernacular name - original'] = 'Eastern bearded dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chlamydosaurus kingii', 'Vernacular name - original'] = 'Frilled-neck lizard'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tropidonophis mairii', 'Vernacular name - original'] = 'Tropidonophis mairii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudechis porphyriacus', 'Vernacular name - original'] = 'Red-bellied black snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Amphibolurus muricatus', 'Vernacular name - original'] = 'Jacky dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus scalaris', 'Vernacular name - original'] = 'Spotted tree monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Notechis scutatus', 'Vernacular name - original'] = 'Tiger snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus gouldii', 'Vernacular name - original'] = 'Sand goanna'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Boiga irregularis', 'Vernacular name - original'] = 'Brown tree snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eulamprus heatwolei', 'Vernacular name - original'] = 'Yellow-bellied water-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia kingii', 'Vernacular name - original'] = 'Egernia kingii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chelonia mydas', 'Vernacular name - original'] = 'Green sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota mcdowelli', 'Vernacular name - original'] = 'Morelia spilota mcdowelli'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Liasis olivaceus', 'Vernacular name - original'] = 'Olive python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lepidodactylus lugubris', 'Vernacular name - original'] = 'Lepidodactylus lugubris'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus giganteus', 'Vernacular name - original'] = 'Perentie'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Intellagama lesueurii howitti', 'Vernacular name - original'] = 'Australian water dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Nebulifera robusta', 'Vernacular name - original'] = 'Robust velvet gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Underwoodisaurus milii', 'Vernacular name - original'] = 'Underwoodisaurus milii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Crocodylus porosus', 'Vernacular name - original'] = 'Saltwater crocodile'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Aspidites melanocephalus', 'Vernacular name - original'] = 'Black-headed python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia napoleonis', 'Vernacular name - original'] = 'South-western crevice-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus pulcher', 'Vernacular name - original'] = 'Elegant snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Austrelaps superbus', 'Vernacular name - original'] = 'Lowland copperhead'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus decresii', 'Vernacular name - original'] = 'Ctenophorus decresii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Simalia kinghorni', 'Vernacular name - original'] = 'Australian scrub python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Antaresia childreni', 'Vernacular name - original'] = 'Children\'s python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra dubia', 'Vernacular name - original'] = 'Dubious dtella'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua nigrolutea', 'Vernacular name - original'] = 'Blotched blue-tongued lizard'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eulamprus tympanum', 'Vernacular name - original'] = 'Southern water skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Bellatorias major', 'Vernacular name - original'] = 'Land mullet'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lampropholis delicata', 'Vernacular name - original'] = 'Rainbow skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus rosenbergi', 'Vernacular name - original'] = 'Rosenberg\'s monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gowidon longirostris', 'Vernacular name - original'] = 'Long-nosed water dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Heteronotia binoei', 'Vernacular name - original'] = 'Heteronotia binoei'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja affinis affinis', 'Vernacular name - original'] = 'Dugite'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lialis burtonis', 'Vernacular name - original'] = 'Burton\'s legless lizard'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja textilis', 'Vernacular name - original'] = 'Eastern brown snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Liopholis slateri', 'Vernacular name - original'] = 'Slater\'s skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Drysdalia coronoides', 'Vernacular name - original'] = 'White-lipped snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus tristis', 'Vernacular name - original'] = 'Black-headed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Antaresia stimsoni', 'Vernacular name - original'] = 'Stimson\'s python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Antaresia maculosa', 'Vernacular name - original'] = 'Spotted python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia psammophis', 'Vernacular name - original'] = 'Yellow-faced whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja nuchalis', 'Vernacular name - original'] = 'Pseudonaja nuchalis'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus taeniolatus', 'Vernacular name - original'] = 'Ctenotus taeniolatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Liopholis whitii', 'Vernacular name - original'] = 'White\'s skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus robustus', 'Vernacular name - original'] = 'Ctenotus robustus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudechis australis', 'Vernacular name - original'] = 'Mulga snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Wollumbinia latisternum', 'Vernacular name - original'] = 'Saw-shelled turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Vermicella annulata', 'Vernacular name - original'] = 'Bandy-bandy'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua scincoides scincoides', 'Vernacular name - original'] = 'Eastern blue-tongued lizard'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia papuensis', 'Vernacular name - original'] = 'Greater black whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Nephrurus amyae', 'Vernacular name - original'] = 'Nephrurus amyae'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lophosaurus boydii', 'Vernacular name - original'] = 'Boyd\'s forest dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Acanthophis hawkei', 'Vernacular name - original'] = 'Acanthophis hawkei'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cyclodomorphus gerrardii', 'Vernacular name - original'] = 'Hemisphaeriodon gerrardii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Stegonotus cucullatus', 'Vernacular name - original'] = 'Slaty-grey snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus ornatus', 'Vernacular name - original'] = 'Ctenophorus ornatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia cunninghami', 'Vernacular name - original'] = 'Cunningham\'s skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chelodina (Macrodiremys) colliei', 'Vernacular name - original'] = 'Southwestern snake-necked turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pogona minor', 'Vernacular name - original'] = 'Pogona minor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Anepischetosia maccoyi', 'Vernacular name - original'] = 'Anepischetosia maccoyi'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura macquarii krefftii', 'Vernacular name - original'] = 'Emydura macquarii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus spinigerus', 'Vernacular name - original'] = 'South-western spiny-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Bellatorias frerei', 'Vernacular name - original'] = 'Land mullet'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiergis peronii', 'Vernacular name - original'] = 'Four-toed earless skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia saxatilis', 'Vernacular name - original'] = 'Egernia saxatilis'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus spaldingi', 'Vernacular name - original'] = 'Straight-browed ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia vestigiata', 'Vernacular name - original'] = 'Lesser black whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eremiascincus richardsonii', 'Vernacular name - original'] = 'Broad-banded sand-swimmer'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiergis decresiensis', 'Vernacular name - original'] = 'Three-toed earless skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Furina diadema', 'Vernacular name - original'] = 'Red-naped snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus inornatus', 'Vernacular name - original'] = 'Bar-shouldered ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra versicolor', 'Vernacular name - original'] = 'Gehyra versicolor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morethia boulengeri', 'Vernacular name - original'] = 'Morethia boulengeri'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Concinnia brachysoma', 'Vernacular name - original'] = 'Northern bar-sided skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Moloch horridus', 'Vernacular name - original'] = 'Thorny devil'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptophis nigrescens', 'Vernacular name - original'] = 'Cryptophis nigrescens'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus caudicinctus', 'Vernacular name - original'] = 'Ctenophorus caudicinctus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tropidechis carinatus', 'Vernacular name - original'] = 'Rough-scaled snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Anomalopus verreauxii', 'Vernacular name - original'] = 'Three-clawed worm-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Natator depressus', 'Vernacular name - original'] = 'Flatback sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pogona vitticeps', 'Vernacular name - original'] = 'Central bearded dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lophosaurus spinipes', 'Vernacular name - original'] = 'Lophosaurus spinipes'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus maculatus', 'Vernacular name - original'] = 'Ctenophorus maculatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Saltuarius swaini', 'Vernacular name - original'] = 'Saltuarius swaini'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Amalosia rhombifer', 'Vernacular name - original'] = 'Amalosia rhombifer'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota imbricata', 'Vernacular name - original'] = 'Morelia spilota imbricata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carinascincus ocellatus', 'Vernacular name - original'] = 'Spotted skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua rugosa aspera', 'Vernacular name - original'] = 'Shingleback'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Rankinia diemensis', 'Vernacular name - original'] = 'Mountain dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua multifasciata', 'Vernacular name - original'] = 'Centralian blue-tongued skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cyclodomorphus casuarinae', 'Vernacular name - original'] = 'She-oak skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gowidon temporalis', 'Vernacular name - original'] = 'Tropicagama'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Aspidites ramsayi', 'Vernacular name - original'] = 'Woma python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiaspis signata', 'Vernacular name - original'] = 'Hemiaspis signata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja mengdeni', 'Vernacular name - original'] = 'Pseudonaja mengdeni'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus pannosus', 'Vernacular name - original'] = 'Ragged snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus vittatus', 'Vernacular name - original'] = 'Diplodactylus vittatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Elseya dentata', 'Vernacular name - original'] = 'Elseya dentata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oedura tryoni', 'Vernacular name - original'] = 'Southern spotted velvet gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Suta suta', 'Vernacular name - original'] = 'Suta suta'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morethia obscura', 'Vernacular name - original'] = 'Shrubland morethia skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chelodina (Macrochelodina) expansa', 'Vernacular name - original'] = 'Chelodina expansa'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oxyuranus scutellatus', 'Vernacular name - original'] = 'Coastal taipan'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Rhynchoedura ornata', 'Vernacular name - original'] = 'Western beaked gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cacophis krefftii', 'Vernacular name - original'] = 'Cacophis krefftii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lophognathus gilberti', 'Vernacular name - original'] = 'Gilbert\'s dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Liasis fuscus', 'Vernacular name - original'] = 'Liasis fuscus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diporiphora nobbi', 'Vernacular name - original'] = 'Nobbi dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudothecadactylus lindneri', 'Vernacular name - original'] = 'Northern giant cave gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia sexdentata', 'Vernacular name - original'] = 'Six-toothed rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia striolata', 'Vernacular name - original'] = 'Tree-crevice skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura victoriae', 'Vernacular name - original'] = 'Emydura victoriae'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra lazelli', 'Vernacular name - original'] = 'Gehyra lazelli'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Concinnia tenuis', 'Vernacular name - original'] = 'Barred-sided Skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus primordius', 'Vernacular name - original'] = 'Northern ridge-tailed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Saltuarius cornutus', 'Vernacular name - original'] = 'Northern leaf-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oedura monilis', 'Vernacular name - original'] = 'Ocellated velvet gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carinascincus metallicus', 'Vernacular name - original'] = 'Carinascincus metallicus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiergis decresiensis continentis', 'Vernacular name - original'] = 'Three-toed earless skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lepidochelys olivacea', 'Vernacular name - original'] = 'Olive ridley sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Liopholis margaretae', 'Vernacular name - original'] = 'Centralian Ranges rock-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Saproscincus mustelinus', 'Vernacular name - original'] = 'Saproscincus mustelinus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oedura castelnaui', 'Vernacular name - original'] = 'Northern velvet gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Concinnia martini', 'Vernacular name - original'] = 'Dark bar-sided skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Furina ornata', 'Vernacular name - original'] = 'Orange-naped snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morethia ruficauda', 'Vernacular name - original'] = 'Lined fire-tailed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Paradelma orientalis', 'Vernacular name - original'] = 'Brigalow scaly-foot'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiergis quadrilineata', 'Vernacular name - original'] = 'Two-toed earless skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus ustulatus', 'Vernacular name - original'] = 'Russet snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Furina tristis', 'Vernacular name - original'] = 'Brown-headed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia torquata', 'Vernacular name - original'] = 'Collared whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carinascincus coventryi', 'Vernacular name - original'] = 'Southern forest cool-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia schmeltzii', 'Vernacular name - original'] = 'Robust rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia rhomboidalis ', 'Vernacular name - original'] = 'Blue-Throated Rainbow-Skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia formosa', 'Vernacular name - original'] = 'Goldfields crevice-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptophis pallidiceps ', 'Vernacular name - original'] = 'Northern small-eyed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oedura marmorata', 'Vernacular name - original'] = 'Marbled velvet gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus taenicauda taenicauda ', 'Vernacular name - original'] = 'Strophurus taenicauda taenicauda'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus nuchalis', 'Vernacular name - original'] = 'Central netted dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Menetia greyii', 'Vernacular name - original'] = 'Common dwarf skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Oedura gemmata', 'Vernacular name - original'] = 'Oedura gemmata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Brachyurophis australis', 'Vernacular name - original'] = 'Australian coral snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Austrelaps ramsayi', 'Vernacular name - original'] = 'Highland copperhead'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lucasium occultum ', 'Vernacular name - original'] = 'Alligator River gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus pictus', 'Vernacular name - original'] = 'Ctenophorus pictus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra australis', 'Vernacular name - original'] = 'Northern dtella'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Dermochelys coriacea', 'Vernacular name - original'] = 'Leatherback sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tympanocryptis centralis', 'Vernacular name - original'] = 'Central Australian earless dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pygopus schraderi', 'Vernacular name - original'] = 'Eastern hooded scaly-foot' 
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus tristis orientalis ', 'Vernacular name - original'] = 'Black-headed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lucasium stenodactylum', 'Vernacular name - original'] = 'crowned gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Chelonia mydas japonica', 'Vernacular name - original'] = 'The green sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptophis boschmai', 'Vernacular name - original'] = 'Carpentaria snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Caretta caretta', 'Vernacular name - original'] = 'Loggerhead sea turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tiliqua rugosa rugosa', 'Vernacular name - original'] = 'Tiliqua rugosa'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura subglobosa subglobosa', 'Vernacular name - original'] = 'Red-bellied short-necked turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja modesta', 'Vernacular name - original'] = 'Ringed brown snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura tanybaraga', 'Vernacular name - original'] = 'Northern yellow-faced turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Saproscincus basiliscus', 'Vernacular name - original'] = 'Pale-lipped shadeskink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus furcosus', 'Vernacular name - original'] = 'Ranges stone gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Emydura macquarii macquarii', 'Vernacular name - original'] = 'Macquarie River turtle'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lissolepis coventryi', 'Vernacular name - original'] = 'Eastern mourning skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenophorus caudicinctus slateri', 'Vernacular name - original'] = 'Ring-tailed dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudemoia spenceri', 'Vernacular name - original'] = 'Trunk-climbing cool-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Glaphyromorphus punctulatus', 'Vernacular name - original'] = 'Fine-spotted mulch-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Indotyphlops braminus', 'Vernacular name - original'] = 'Brahminy blind snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gnypetoscincus queenslandiae', 'Vernacular name - original'] = 'Prickly forest skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lerista bougainvillii', 'Vernacular name - original'] = 'South-eastern slider'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ophioscincus ophioscincus', 'Vernacular name - original'] = 'Yolk-bellied snake-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Parasuta dwyeri', 'Vernacular name - original'] = 'Dwyer\'s snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Drysdalia mastersii', 'Vernacular name - original'] = 'Masters\' snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra variegata', 'Vernacular name - original'] = 'Gehyra variegata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eremiascincus fasciolatus', 'Vernacular name - original'] = 'Eastern narrow-banded skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lygisaurus foliorum', 'Vernacular name - original'] = 'Tree-base litter-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus baritji', 'Vernacular name - original'] = 'Black-spotted ridge-tailed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Nephrurus levis', 'Vernacular name - original'] = 'Three-lined Knob-tail'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudemoia rawlinsoni', 'Vernacular name - original'] = 'Glossy grass skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diporiphora pindang', 'Vernacular name - original'] = 'Pindan two-lined dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Saproscincus challengeri', 'Vernacular name - original'] = 'Orange-tailed shadeskink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota cheynei', 'Vernacular name - original'] = 'Morelia spilota cheynei'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota spilota', 'Vernacular name - original'] = 'Diamond Python'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia stokesii', 'Vernacular name - original'] = 'Egernia stokesii'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Nephrurus sheai', 'Vernacular name - original'] = 'Kimberley rough knob-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Acritoscincus trilineatus', 'Vernacular name - original'] = 'Western three-lined skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Parasuta flagellum', 'Vernacular name - original'] = ' Little whip snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Echiopsis curta', 'Vernacular name - original'] = ' Bardick'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia olivacea', 'Vernacular name - original'] = 'Olive whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus conspicillatus', 'Vernacular name - original'] = 'Variable fat-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diporiphora australis', 'Vernacular name - original'] = 'Tommy roundhead'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diporiphora albilabris', 'Vernacular name - original'] = 'White-lipped two-lined dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus jeanae', 'Vernacular name - original'] = ' Southern phasmid gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus australis', 'Vernacular name - original'] = 'Western limestone ctenotus'

Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Delma tincta', 'Vernacular name - original'] = 'Excitable delma'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Tympanocryptis lineata', 'Vernacular name - original'] = 'Eastern Lined Earless Dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus plagiocephalus', 'Vernacular name - original'] = 'Péron\'s snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptophis pallidiceps', 'Vernacular name - original'] = 'Northern small-eyed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus taenicauda taenicauda', 'Vernacular name - original'] = 'Golden-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lucasium occultum', 'Vernacular name - original'] = 'Alligator River gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Simoselaps anomalus', 'Vernacular name - original'] = 'Desert banded snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus virgatus', 'Vernacular name - original'] = 'Wall skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus tristis orientalis', 'Vernacular name - original'] = 'Black-headed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus wellingtonae', 'Vernacular name - original'] = 'Western Shield spiny-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus ciliaris', 'Vernacular name - original'] = 'Northern spiny-tailed gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lissolepis luctuosa', 'Vernacular name - original'] = 'Western mourning skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Silvascincus murrayi', 'Vernacular name - original'] = 'Blue-speckled Forest-Skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia munda', 'Vernacular name - original'] = 'Shaded-litter rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia decora', 'Vernacular name - original'] = 'Elegant rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia rhomboidalis', 'Vernacular name - original'] = 'Blue-throated Rainbow-Skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus glebopalma', 'Vernacular name - original'] = 'Black-palmed rock monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lerista punctatovittata', 'Vernacular name - original'] = 'Eastern robust slider'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus bilybara', 'Vernacular name - original'] = 'Western fat-tailed geckov'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diporiphora pindan', 'Vernacular name - original'] = 'Pindan two-lined dragon'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Parasuta nigriceps', 'Vernacular name - original'] = 'Mitchell\'s short-tailed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus arcanus', 'Vernacular name - original'] = 'Arcane ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cyclodomorphus branchialis', 'Vernacular name - original'] = 'Gilled slender blue-tongue'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pygopus steelescotti', 'Vernacular name - original'] = 'Northern hooded scaly-foot'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lucasium immaculatum', 'Vernacular name - original'] = 'Pale-striped ground gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Anilios nigrescens', 'Vernacular name - original'] = 'Blackish blind snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lerista edwardsae', 'Vernacular name - original'] = 'Edwards\' slider'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Hemiergis gracilipes', 'Vernacular name - original'] = 'South-western mulch-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus metallicus', 'Vernacular name - original'] = 'Metallic snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Gehyra purpurascens', 'Vernacular name - original'] = 'Purplish dtella'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus labillardieri', 'Vernacular name - original'] = 'Common south-west ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus acanthurus acanthurus', 'Vernacular name - original'] = 'Spiny-tailed monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus calcicolus', 'Vernacular name - original'] = 'South coast gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudemoia entrecasteauxii', 'Vernacular name - original'] = 'Southern grass skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Calyptotis scutirostrum', 'Vernacular name - original'] = 'Scute-snouted calyptotis'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Notoscincus butleri', 'Vernacular name - original'] = 'Notoscincus butleri'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus catenifer', 'Vernacular name - original'] = 'Chain-striped south-west ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Brachyurophis incinctus', 'Vernacular name - original'] = 'Unbanded shovel-nosed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia simplex', 'Vernacular name - original'] = 'Grey whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia amax', 'Vernacular name - original'] = 'Two-spined rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Eulamprus kosciuskoi', 'Vernacular name - original'] = 'Alpine water skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Delma torquata', 'Vernacular name - original'] = 'Collared delma'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lerista praepedita', 'Vernacular name - original'] = 'Western worm lerista'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus essingtonii', 'Vernacular name - original'] = 'Essingtonian ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ctenotus regius', 'Vernacular name - original'] = 'Pale-rumped ctenotus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Ophioscincus cooloolensis', 'Vernacular name - original'] = 'Cooloola snake-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus panoptes panoptes', 'Vernacular name - original'] = 'Argus monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Brachyurophis approximans', 'Vernacular name - original'] = 'North-western shovel-nosed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Notoscincus ornatus', 'Vernacular name - original'] = 'Ornate soil-crevice skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Anilios bituberculatus', 'Vernacular name - original'] = 'Prong-snouted blind snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Strophurus elderi', 'Vernacular name - original'] = 'Jewelled gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus semiremex', 'Vernacular name - original'] = 'Rusty monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carphodactylus laevis', 'Vernacular name - original'] = 'Chameleon gecko'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morethia taeniopleura', 'Vernacular name - original'] = 'Fire-tailed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cryptoblepharus wulbu', 'Vernacular name - original'] = 'Spangled snake-eyed skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudonaja aspidorhyncha', 'Vernacular name - original'] = 'Strap-snouted brown snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Brachyurophis roperi', 'Vernacular name - original'] = 'Northern shovel-nosed snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cerberus australis', 'Vernacular name - original'] = 'Australian bockadam'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Carlia pectoralis', 'Vernacular name - original'] = 'Open-litter rainbow-skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Delma nasuta', 'Vernacular name - original'] = 'Delma nasuta'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Neelaps bimaculatus', 'Vernacular name - original'] = 'Black-naped snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Varanus glauerti', 'Vernacular name - original'] = 'Kimberley rock monitor'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Egernia saxatilis intermedia', 'Vernacular name - original'] = 'Egernia saxatilis'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morelia spilota variegata', 'Vernacular name - original'] = 'Morelia spilota variegata'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Demansia reticulata', 'Vernacular name - original'] = 'Reticulated whipsnake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus tessellatus', 'Vernacular name - original'] = 'Diplodactylus tessellatus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Morethia butleri', 'Vernacular name - original'] = 'Woodland morethia skink'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Diplodactylus platyurus', 'Vernacular name - original'] = 'Diplodactylus platyurus'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Pseudoferania polylepis', 'Vernacular name - original'] = 'Macleay\'s water snake'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Lerista carpentariae', 'Vernacular name - original'] = 'Bungle Bungle robust slider'
Reptiles_1998.loc[Reptiles_1998['Scientific Name'] == 'Cyclodomorphus celatus', 'Vernacular name - original'] = 'Western slender blue-tongue'

# %%
# Take the rows where the English name is not null in 1998

Reptiles_1998 = Reptiles_1998[Reptiles_1998['Vernacular name - original'].notnull()]

# %%
# Read 2019 data for amphibians, mammals and reptiles

Amphibians_2019 = pd.read_csv("ANIMALS.csv")

# %%
# Calculate the frequency of the English names for 1998
 
Reptiles_1998['freq'] = Reptiles_1998.groupby('Vernacular name - original')['Vernacular name - original'].transform('count')

# Drop rows with English name duplicates in 1998

Reptiles_1998.drop_duplicates(subset ="Vernacular name - original", keep = "first", inplace = True)

# %%
# Check the first 5 rows in 1998

Reptiles_1998.head()
# Out:
#   Vernacular name - original       Scientific Name Taxon Rank   Kingdom  \
# 0             Tiliqua rugosa        Tiliqua rugosa    species  Animalia
# 1       Ctenotus taeniolatus  Ctenotus taeniolatus    species  Animalia
# 2          Ctenotus robustus     Ctenotus robustus    species  Animalia
# 3                Tiger snake     Notechis scutatus    species  Animalia
# 4        Four-fingered Skink   Carlia tetradactyla    species  Animalia
#
#      Phylum     Class     Family     Genus  Latitude  Longitude  \
# 0  Chordata  Reptilia  Scincidae   Tiliqua   -35.320    148.950
# 1  Chordata  Reptilia  Scincidae  Ctenotus   -35.237    148.955
# 2  Chordata  Reptilia  Scincidae  Ctenotus   -35.237    148.955
# 3  Chordata  Reptilia   Elapidae  Notechis   -35.287    149.163
# 4  Chordata  Reptilia  Scincidae    Carlia   -35.396    149.009
#
#   Country - parsed                State - parsed  Year  freq
# 0        Australia  Australian Capital Territory  1998    81
# ...

# %%
# Add the frequency in 1998 to 2019

for index, row in Amphibians_2019.iterrows():
    species = row['Vernacular name - original']
    if any(Reptiles_1998['Vernacular name - original'] == species):
        Amphibians_2019.at[index,'1998'] = Reptiles_1998.loc[Reptiles_1998['Vernacular name - original'] == species, 'freq'].iloc[0]

# %%
# Check the first 5 rows in 2019

Amphibians_2019.head()
# Out:
#   Vernacular name - original     Scientific Name Taxon Rank   Kingdom  \
# 0     Slender-tailed dunnart  Sminthopsis murina    species  Animalia
# 1     Slender-tailed dunnart  Sminthopsis murina    species  Animalia
# 2     Slender-tailed dunnart  Sminthopsis murina    species  Animalia
# 3           Common Planigale  Planigale maculata    species  Animalia
# 4           Gehyra variegata    Gehyra variegata    species  Animalia
#
#      Phylum     Class      Family        Genus   Latitude   Longitude  ...   \
# 0  Chordata  Mammalia  Dasyuridae  Sminthopsis -29.539333  153.090917  ...
# 1  Chordata  Mammalia  Dasyuridae  Sminthopsis -32.380600  151.013600  ...
# 2  Chordata  Mammalia  Dasyuridae  Sminthopsis -34.500000  150.400000  ...
# 3  Chordata  Mammalia  Dasyuridae    Planigale -29.633753  153.216922  ...
# 4  Chordata  Reptilia  Gekkonidae       Gehyra -31.960032  116.032948  ...
#
#    Year freq  Count_1968  Rate_1968  No   1978  1988   1998   2008  2018
# ...

# %%
# Update the 2019 file

Amphibians_2019.to_csv('ANIMALS.csv', sep=',', encoding='utf-8', index = False)
